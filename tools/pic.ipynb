# %%
import pylab
import numpy as np

path = '/home/jovyan/pic/pic_guid.jpg'
im = pylab.imread(path)
im_1 = im[0:340,2350:2625]

im_n = np.array(im.shape)
#im[0:340,2350:2625] = im[0:340,1750:2225]

pylab.imshow(im_1)

pylab.show()

# %%
pwd
# Out:
# '/home/jovyan/pic'
